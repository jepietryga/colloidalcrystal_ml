# %% [markdown]
# Use this notebook for segmenting and classifying new data.

# %%
import cv2
import numpy as np
import glob
from matplotlib import pyplot as plt
from scipy import ndimage
from skimage import measure, color, io
import math
import copy
import pandas as pd
import os

import sys
sys.path.append("..")
from Utility.segmentation_utils import *

# %%
files = ['../Images/Training/4 nM 7.bmp',
            '../Images/Training/39.5 hold 3.bmp']

# A ton of default parameters exist for this class, make sure to check segmentation_utils.py
IS = ImageSegmenter(files[0],override_exists=True,file_str="TEST_adjust_label_increment")
# Out:
# Image Segmenter on 4 nM 7 created!

# %%
plt.imshow(IS.img)

# %%
IS.decorate_regions() # Adds centroids and numeric labels to img4
plt.imshow(IS.img4)

# %%
plt.imshow(IS.markers)

# %%
IS.begin_labeling()
# Out:
# Region 1 (Max: 32)
# NOTE: Skipping a region may mean a bad region was encountered
#
# Type an integer to jump to region, or a character below to label image
#  C = Crystal, M = Multiple Crystal, P = Poorly Segmented, I = Incomplete, B = Back, D = Done
# C
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 IS.begin_labeling()
#
# File ~/Desktop/Academics/Mirkin/colloidal_crystal_ML/Notebooks/../Utility/segmentation_utils.py:402, in ImageSegmenter.begin_labeling(self)
#     400 elif user_input == 'I':
#     401     translated_input = 'Incomplete'
# --> 402 self.df.at[self.df['Region'] == region_oi,'Labels'] = translated_input
#     403 self.df.to_csv(self._csv_file)
#     405 ii = ii + 1
#
# File ~/anaconda3/envs/cc_env/lib/python3.9/site-packages/pandas/core/indexing.py:2281, in _AtIndexer.__setitem__(self, key, value)
# ...

# %%
IS.create_csv()
