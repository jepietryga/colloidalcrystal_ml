# %%
import sys
sys.path.append("..")
import os
from pathlib import Path
from facet_ml.segmentation.segmenter import ImageSegmenter

im = "/Users/jacobpietryga/Desktop/Academics/colloidal_crystal_ML/Images/DiagnosticImages_tifs/Au_sphere_20nm_substrate_SiO2_04.tif"
path = os.path.abspath()
IS = ImageSegmenter(im)

# %%
IS.to_h5("test.h5")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 IS.to_h5("test.h5")
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:732, in ImageSegmenter.to_h5(self, file_name, mode)
#     729 group = f.create_group(group_name)
#     731 group.create_dataset("input_path", data=self.input_path)
# --> 732 group.create_dataset("input_image", data=self.image_read)
#     733 group.create_dataset("image_cropped", data=self.image_cropped)
#     734 group.create_dataset("image_working", data=self.image_working)
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:523, in ImageSegmenter.image_read(self)
#     520 @property
#     521 def image_read(self):
#     522     if self._image_read is None:
# --> 523         self.process_images()
#     524     return self._image_read
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:566, in ImageSegmenter.process_images(self)
#     564 # Raw Read-in
#     565 self._image_read = cv2.imread(self.input_path, 0)
# --> 566 self._image_cropped = self.image_read[
#     567     self.top_boundary : self.bottom_boundary,
#     568     self.left_boundary : self.right_boundary,
#     569 ]
#     570 self._image_working = cv2.imread(self.input_path, 1)
#     571 self._image_working = self.image_working[
#     572     self.top_boundary : self.bottom_boundary,
#     573     self.left_boundary : self.right_boundary,
#     574 ]
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:523, in ImageSegmenter.image_read(self)
#     520 @property
#     521 def image_read(self):
#     522     if self._image_read is None:
# --> 523         self.process_images()
#     524     return self._image_read
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:566, in ImageSegmenter.process_images(self)
#     564 # Raw Read-in
#     565 self._image_read = cv2.imread(self.input_path, 0)
# --> 566 self._image_cropped = self.image_read[
#     567     self.top_boundary : self.bottom_boundary,
#     568     self.left_boundary : self.right_boundary,
#     569 ]
#     570 self._image_working = cv2.imread(self.input_path, 1)
#     571 self._image_working = self.image_working[
#     572     self.top_boundary : self.bottom_boundary,
#     573     self.left_boundary : self.right_boundary,
#     574 ]
#
#     [... skipping similar frames: ImageSegmenter.image_read at line 523 (1251 times), ImageSegmenter.process_images at line 566 (1250 times)]
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:566, in ImageSegmenter.process_images(self)
#     564 # Raw Read-in
#     565 self._image_read = cv2.imread(self.input_path, 0)
# --> 566 self._image_cropped = self.image_read[
#     567     self.top_boundary : self.bottom_boundary,
#     568     self.left_boundary : self.right_boundary,
#     569 ]
#     570 self._image_working = cv2.imread(self.input_path, 1)
#     571 self._image_working = self.image_working[
#     572     self.top_boundary : self.bottom_boundary,
#     573     self.left_boundary : self.right_boundary,
#     574 ]
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:523, in ImageSegmenter.image_read(self)
#     520 @property
#     521 def image_read(self):
#     522     if self._image_read is None:
# --> 523         self.process_images()
#     524     return self._image_read
#
# File ~\Desktop\Academics\Mirkin\colloidal_crystal_ML\facet_ml\segmentation\segmenter.py:565, in ImageSegmenter.process_images(self)
#     562     raise Exception("Error: ImageSegmenter has no input_path")
#     564 # Raw Read-in
# --> 565 self._image_read = cv2.imread(self.input_path, 0)
#     566 self._image_cropped = self.image_read[
#     567     self.top_boundary : self.bottom_boundary,
#     568     self.left_boundary : self.right_boundary,
#     569 ]
#     570 self._image_working = cv2.imread(self.input_path, 1)
#
# error: Unknown C++ exception from OpenCV code

# %%
import h5py
f = h5py.File("test.h5","r")
f.keys()

import matplotlib.pyplot as plt
plt.imshow(f["input_image"])
