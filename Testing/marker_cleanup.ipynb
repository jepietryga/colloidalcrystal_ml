# %%
import sys
sys.path.append("..")
from facet_ml.segmentation.segmenter import ImageSegmenter
import matplotlib.pyplot as plt

img_path = "/Users/jacobpietryga/Desktop/Academics/colloidal_crystal_ML/Images/Training/4 nM 1.bmp"
img_path = "/Users/jacobpietryga/Desktop/Academics/colloidal_crystal_ML/Images/Figure2_Images/AuNP-octahedron/2013-08-02 Dried Octahedra 8_i006.jpg"

# %%
IS  = ImageSegmenter(img_path)

IS.markers2
plt.imshow(IS.markers2)

# %%
plt.imshow(IS._clean_markers2())

import pickle
model_path = "/Users/jacobpietryga/Desktop/Academics/colloidal_crystal_ML/facet_ml/static/Models/model_set__original_2023_classifier/C_MC_I_P.sav"
with open(model_path,"rb") as f:
    model = pickle.load(f)

import json
feature_path = "/Users/jacobpietryga/Desktop/Academics/colloidal_crystal_ML/facet_ml/classification/config_files/config_features.json"
with open(feature_path,"r") as f:

    features = json.load(feature_path)
    feature_load.json
